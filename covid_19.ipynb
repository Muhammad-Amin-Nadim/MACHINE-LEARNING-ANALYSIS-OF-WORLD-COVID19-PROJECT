# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b3f2b23b-e887-4061-af12-88ecc89a50a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3f2b23b-e887-4061-af12-88ecc89a50a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid.csv to covid.csv

# %%
covid = pd.read_csv('covid.csv')

# %%
#Having a glance at some of the records
covid.head()
# Out:
#   iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 0      ABW    Aruba  ...                    NaN                     NaN
# 1      ABW    Aruba  ...                    NaN                     NaN
# 2      ABW    Aruba  ...                    NaN                     NaN
# 3      ABW    Aruba  ...                    NaN                     NaN
# 4      ABW    Aruba  ...                    NaN                     NaN
#
# [5 rows x 32 columns]

# %%
#Looking at the shape
covid.shape
# Out:
# (19496, 32)

# %%
covid.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
#Looking at the different locations
covid["location"].value_counts()
# Out:
# Netherlands       146
# Switzerland       146
# Norway            146
# United States     146
# Austria           146
#                  ...
# Yemen              45
# Western Sahara     29
# Tajikistan         24
# Comoros            23
# Lesotho            10
# Name: location, Length: 212, dtype: int64

# %%
#Checking if columns have null values
covid.isna().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# aged_70_older                       True
# gdp_per_capita                      True
# extreme_poverty                     True
# cvd_death_rate                      True
# diabetes_prevalence                 True
# female_smokers                      True
# male_smokers                        True
# handwashing_facilities              True
# hospital_beds_per_100k              True
# dtype: bool

# %%
#Getting the sum of null values across each column
covid.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14332
# new_tests                          14904
# total_tests_per_thousand           14332
# new_tests_per_thousand             14904
# new_tests_smoothed                 13866
# new_tests_smoothed_per_thousand    13866
# tests_units                        13267
# stringency_index                    4500
# population                            64
# population_density                   850
# median_age                          1743
# aged_65_older                       1980
# aged_70_older                       1832
# gdp_per_capita                      1982
# extreme_poverty                     7878
# cvd_death_rate                      1817
# diabetes_prevalence                 1174
# female_smokers                      5052
# male_smokers                        5206
# handwashing_facilities             11822
# hospital_beds_per_100k              3160
# dtype: int64

# %%
#Getting the cases in India
USA_case=covid[covid["location"]=="United States"]

# %%
USA_case.head()
# Out:
#       iso_code       location  ... handwashing_facilities  hospital_beds_per_100k
# 18246      USA  United States  ...                    NaN                    2.77
# 18247      USA  United States  ...                    NaN                    2.77
# 18248      USA  United States  ...                    NaN                    2.77
# 18249      USA  United States  ...                    NaN                    2.77
# 18250      USA  United States  ...                    NaN                    2.77
#
# [5 rows x 32 columns]

# %%
USA_case.tail()
# Out:
#       iso_code       location  ... handwashing_facilities  hospital_beds_per_100k
# 18387      USA  United States  ...                    NaN                    2.77
# 18388      USA  United States  ...                    NaN                    2.77
# 18389      USA  United States  ...                    NaN                    2.77
# 18390      USA  United States  ...                    NaN                    2.77
# 18391      USA  United States  ...                    NaN                    2.77
#
# [5 rows x 32 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#Total cases per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=USA_case)
plt.show()

# %%
#Making a dataframe for last 5 days
USA_last_5_days=USA_case.tail()

# %%
#Total cases in last 5 days
sns.set(rc={'figure.figsize':(3,3)})
sns.lineplot(x="date",y="total_cases",data=USA_last_5_days)
plt.show()

# %%
#Total tests per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=USA_case)
plt.show()

# %%
#Total tests in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=USA_last_5_days)
plt.show()

# %%
#Brazil Case
brazil_case=covid[covid["location"]=="Brazil"] 
brazil_case.head()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 2510      BRA   Brazil  ...                    NaN                     2.2
# 2511      BRA   Brazil  ...                    NaN                     2.2
# 2512      BRA   Brazil  ...                    NaN                     2.2
# 2513      BRA   Brazil  ...                    NaN                     2.2
# 2514      BRA   Brazil  ...                    NaN                     2.2
#
# [5 rows x 32 columns]

# %%
brazil_case.tail()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 2651      BRA   Brazil  ...                    NaN                     2.2
# 2652      BRA   Brazil  ...                    NaN                     2.2
# 2653      BRA   Brazil  ...                    NaN                     2.2
# 2654      BRA   Brazil  ...                    NaN                     2.2
# 2655      BRA   Brazil  ...                    NaN                     2.2
#
# [5 rows x 32 columns]

# %%
#Making a dataframe for brazil for last 5 days
brazil_last_5_days=brazil_case.tail()

# %%
#Total cases in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=brazil_last_5_days)
plt.show()

# %%
#Understanding cases of USA, China and Japan
USA_japan_china=covid[(covid["location"] =="United States") | (covid["location"] =="China") | (covid["location"]=="Japan")]

# %%
#Plotting growth of cases across China, India and Japan
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=USA_japan_china,hue="date")
plt.show()

# %%
#Understanding cases of germany and spain
germany_spain=covid[(covid["location"] =="Germany") | (covid["location"] =="Spain")]

# %%
#Plotting growth of cases across Germany and Spain
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=germany_spain,hue="date")
plt.show()

# %%
#Getting latest data
last_day_cases=covid[covid["date"]=="2020-05-24"]
last_day_cases
# Out:
#        iso_code      location  ... handwashing_facilities  hospital_beds_per_100k
# 62          ABW         Aruba  ...                    NaN                     NaN
# 198         AFG   Afghanistan  ...                 37.746                   0.500
# 262         AGO        Angola  ...                 26.664                     NaN
# 321         AIA      Anguilla  ...                    NaN                     NaN
# 398         ALB       Albania  ...                    NaN                   2.890
# ...         ...           ...  ...                    ...                     ...
# 19045       YEM         Yemen  ...                 49.542                   0.700
# 19153       ZAF  South Africa  ...                 43.993                   2.320
# 19220       ZMB        Zambia  ...                 13.938                   2.000
# 19285       ZWE      Zimbabwe  ...                 36.791                   1.700
# 19431  OWID_WRL         World  ...                 60.130                   2.705
#
# [207 rows x 32 columns]

# %%
#Sorting data w.r.t total_cases
max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
#        iso_code  ... hospital_beds_per_100k
# 19431  OWID_WRL  ...                  2.705
# 18391       USA  ...                  2.770
# 2655        BRA  ...                  2.200
# 15569       RUS  ...                  8.050
# 9396        ITA  ...                  3.180
# ...         ...  ...                    ...
# 18723       VGB  ...                    NaN
# 1645        BES  ...                    NaN
# 5543        ESH  ...                    NaN
# 321         AIA  ...                    NaN
# 11086       LSO  ...                    NaN
#
# [207 rows x 32 columns]

# %%
#Top 5 countries with maximum cases
max_cases_country[1:6]
# Out:
#       iso_code       location  ... handwashing_facilities  hospital_beds_per_100k
# 18391      USA  United States  ...                    NaN                    2.77
# 2655       BRA         Brazil  ...                    NaN                    2.20
# 15569      RUS         Russia  ...                    NaN                    8.05
# 9396       ITA          Italy  ...                    NaN                    3.18
# 4613       DEU        Germany  ...                    NaN                    8.00
#
# [5 rows x 32 columns]

# %%
#Making bar-plot for countries with top cases
sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="location")
plt.show()

# %%
USA_case.head()
# Out:
#       iso_code       location  ... handwashing_facilities  hospital_beds_per_100k
# 18246      USA  United States  ...                    NaN                    2.77
# 18247      USA  United States  ...                    NaN                    2.77
# 18248      USA  United States  ...                    NaN                    2.77
# 18249      USA  United States  ...                    NaN                    2.77
# 18250      USA  United States  ...                    NaN                    2.77
#
# [5 rows x 32 columns]

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
#converting string date to date-time
import datetime as dt
USA_case['date'] = pd.to_datetime(USA_case['date']) 
USA_case.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       iso_code       location  ... handwashing_facilities  hospital_beds_per_100k
# 18246      USA  United States  ...                    NaN                    2.77
# 18247      USA  United States  ...                    NaN                    2.77
# 18248      USA  United States  ...                    NaN                    2.77
# 18249      USA  United States  ...                    NaN                    2.77
# 18250      USA  United States  ...                    NaN                    2.77
#
# [5 rows x 32 columns]

# %%
USA_case.head()
# Out:
#       iso_code       location  ... handwashing_facilities  hospital_beds_per_100k
# 18246      USA  United States  ...                    NaN                    2.77
# 18247      USA  United States  ...                    NaN                    2.77
# 18248      USA  United States  ...                    NaN                    2.77
# 18249      USA  United States  ...                    NaN                    2.77
# 18250      USA  United States  ...                    NaN                    2.77
#
# [5 rows x 32 columns]

# %%
#converting date-time to ordinal
USA_case['date']=USA_case['date'].map(dt.datetime.toordinal)
USA_case.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       iso_code       location  ...  handwashing_facilities  hospital_beds_per_100k
# 18246      USA  United States  ...                     NaN                    2.77
# 18247      USA  United States  ...                     NaN                    2.77
# 18248      USA  United States  ...                     NaN                    2.77
# 18249      USA  United States  ...                     NaN                    2.77
# 18250      USA  United States  ...                     NaN                    2.77
#
# [5 rows x 32 columns]

# %%
#getting dependent variable and inpedent variable
x=USA_case['date']
y=USA_case['total_cases']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
import numpy as np
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
USA_case.tail()
# Out:
#       iso_code       location  ...  handwashing_facilities  hospital_beds_per_100k
# 18387      USA  United States  ...                     NaN                    2.77
# 18388      USA  United States  ...                     NaN                    2.77
# 18389      USA  United States  ...                     NaN                    2.77
# 18390      USA  United States  ...                     NaN                    2.77
# 18391      USA  United States  ...                     NaN                    2.77
#
# [5 rows x 32 columns]

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 517035162036.4295

# %%
lr.predict(np.array([[737573]]))
# Out:
# array([[47267.72008687]])
